# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets  
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
fraud = pd.read_csv("D:/Data Science/Data Science/Assignments/15 Random Forests/Fraud_check.csv")

# %%
fraud.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
fraud = fraud.rename(columns={'Marital.Status':'Marital_Status', 'Taxable.Income':'Taxable_Income','Work.Experience':'Work_Experience','City.Population':'City_Population'})

# %%
fraud['income_range'] = np.where(fraud['Taxable_Income']>=30000, 'Good', 'Risky')
fraud.head()
# Out:
#   Undergrad Marital_Status  Taxable_Income  City_Population  Work_Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban income_range
# 0   YES         Good
# 1   YES         Good
# 2   YES         Good
# 3   YES         Good
# 4    NO         Good

# %%
sns.pairplot(fraud,hue='income_range')

# %%
fraud['income_range'].value_counts().plot.pie()
plt.show()
print(fraud['income_range'].value_counts())
# Out:
# Good     476
# Risky    124
# Name: income_range, dtype: int64

# %%
fraud['Marital_Status'].value_counts().plot.pie()
plt.show()
print(fraud['Marital_Status'].value_counts())
# Out:
# Single      217
# Married     194
# Divorced    189
# Name: Marital_Status, dtype: int64

# %%
fraud['Work_Experience'].value_counts(sort=True).plot.bar()
plt.show()
print(fraud['Work_Experience'].value_counts())
# Out:
# 10    31
# 13    28
# 12    25
# 30    25
# 28    25
# 14    24
# 11    23
# 21    23
# 26    22
# 5     22
# 27    22
# 7     21
# 19    21
# 29    21
# 25    19
# 2     19
# 6     19
# 16    19
# 15    18
# 17    18
# 24    17
# 23    16
# 20    15
# 8     14
# 4     14
# 3     14
# 1     14
# 0     14
# 9     13
# 22    13
# 18    11
# Name: Work_Experience, dtype: int64

# %%
fraud['Urban'].value_counts().plot.pie()
plt.show()
print(fraud['Urban'].value_counts())
# Out:
# YES    302
# NO     298
# Name: Urban, dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder()
fraud_data = fraud[['Undergrad', 'Marital_Status','Urban']].apply(label_encoder.fit_transform)
fraud_data = fraud_data.rename(columns={'Undergrad':'Undergrad_numeric', 'Marital_Status':'Marital_Status_numeric','Urban':'Urban_numeric'})

# %%
fraud_data.head()
# Out:
#    Undergrad_numeric  Marital_Status_numeric  Urban_numeric
# 0                  0                       2              1
# 1                  1                       0              1
# 2                  0                       1              1
# 3                  1                       2              1
# 4                  0                       1              0

# %%
fraud_data = pd.concat([fraud,fraud_data], axis=1, sort=False)
fraud_data.head()
# Out:
#   Undergrad Marital_Status  Taxable_Income  City_Population  Work_Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban income_range  Undergrad_numeric  Marital_Status_numeric  Urban_numeric
# 0   YES         Good                  0                       2              1
# 1   YES         Good                  1                       0              1
# 2   YES         Good                  0                       1              1
# 3   YES         Good                  1                       2              1
# 4    NO         Good                  0                       1              0

# %%
fraud_data.drop(columns={'Undergrad','Marital_Status','Urban','Taxable_Income'},axis=1)
# Out:
#      City_Population  Work_Experience income_range  Undergrad_numeric  \
# 0              50047               10         Good                  0
# 1             134075               18         Good                  1
# 2             160205               30         Good                  0
# 3             193264               15         Good                  1
# 4              27533               28         Good                  0
# ..               ...              ...          ...                ...
# 595            39492                7         Good                  1
# 596            55369                2         Good                  1
# 597           154058                0         Good                  0
# 598           180083               17         Good                  1
# 599           158137               16         Good                  0
#
#      Marital_Status_numeric  Urban_numeric
# 0                         2              1
# 1                         0              1
# 2                         1              1
# 3                         2              1
# 4                         1              0
# ..                      ...            ...
# 595                       0              1
# 596                       0              1
# 597                       0              1
# 598                       1              0
# 599                       0              0
#
# [600 rows x 6 columns]

# %%
fraud_data = fraud_data[['City_Population','Work_Experience','Undergrad_numeric','Marital_Status_numeric','Urban_numeric','income_range']]

# %%
fraud_data.head()
# Out:
#    City_Population  Work_Experience  Undergrad_numeric  \
# 0            50047               10                  0
# 1           134075               18                  1
# 2           160205               30                  0
# 3           193264               15                  1
# 4            27533               28                  0
#
#    Marital_Status_numeric  Urban_numeric income_range
# 0                       2              1         Good
# 1                       0              1         Good
# 2                       1              1         Good
# 3                       2              1         Good
# 4                       1              0         Good

# %%
colnames=list(fraud_data.columns)
colnames
# Out:
# ['City_Population',
#  'Work_Experience',
#  'Undergrad_numeric',
#  'Marital_Status_numeric',
#  'Urban_numeric',
#  'income_range']

# %%
fraud_data.income_range.value_counts()
# Out:
# Good     476
# Risky    124
# Name: income_range, dtype: int64

# %%
fraud_data.isnull().sum()
# Out:
# City_Population           0
# Work_Experience           0
# Undergrad_numeric         0
# Marital_Status_numeric    0
# Urban_numeric             0
# income_range              0
# dtype: int64

# %%
x=fraud_data.iloc[:,0:5]
y=fraud_data['income_range']

# %%
# Splitting data into training and testing data set
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=0)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
num_trees = 400
max_features = 4
kfold = KFold(n_splits=10)
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_features=4, n_estimators=400)

# %%
accuracy_score(y_test,model.predict(x_test))
# Out:
# 0.75

# %%
confusion_matrix(y_test,model.predict(x_test))
# Out:
# array([[88,  7],
#        [23,  2]], dtype=int64)

# %%
preds= model.predict(x_test)

# %%
pd.Series(preds).value_counts()
# Out:
# Good     111
# Risky      9
# dtype: int64

# %%
preds
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Risky', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good',
#        'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky',
#        'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good'],
#       dtype=object)

# %%
pd.crosstab(y_test,preds)
# Out:
# col_0         Good  Risky
# income_range
# Good            88      7
# Risky           23      2

# %%
np.mean(preds==y_test)
# Out:
# 0.75
